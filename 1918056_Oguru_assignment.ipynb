# %% [markdown]
# # Emart Online Shopping - Assignment
# Deadline: October 04, 11 AM. Send it to my email.
#
# We have created a fabricated data about some purchases done via Emart Online Shopping! You are required to do the tasks.Usually your answer is just one line of code. Make sure to have have the attached 'Emart Online Shopping'dataset!

# %%
#Q1: Run pandas lib
import pandas as pd

# %%
#Q2: Read the attached CSV dataset 'Emart Online Shopping'
emart = pd.read_csv("C:/Users/oguru/Downloads/Emart Online Shopping")

# %%
#Q3: Display head of the'Emart Online Shopping' dataset 
emart.describe()
emart.head()
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# 2       Simpson, Williams and Pham      675957666125       08/19
# 3  Williams, Marshall and Buchanan  6011578504430710       02/24
# 4        Brown, Watson and Andrews  6011456623207998       10/25
#
#    CC Security Code                  CC Provider  \
# 0               900                 JCB 16 digit
# 1               561                   Mastercard
# 2               699                 JCB 16 digit
# 3               384                     Discover
# 4               678  Diners Club / Carte Blanche
#
#                             Email                                     Job  \
# 0               pdunlap@yahoo.com  Scientist, product/process development
# 1              anthony41@reed.com                       Drilling engineer
# 2  amymiller@morales-harrison.com                Customer service manager
# 3     brent16@olson-robinson.info                       Drilling engineer
# 4     christopherwright@gmail.com                             Fine artist
#
#         IP Address Language  Purchase Price
# 0  149.146.147.205       el           98.14
# 1     15.160.41.51       fr           70.73
# 2   132.207.160.22       de            0.95
# 3     30.250.74.19       es           78.04
# 4     24.140.33.94       es           77.82

# %%
# Q4. check number of rows and columns
emart.shape
# Out:
# (10000, 14)

# %%
#Q5: Calculate average of the Purchase?
purchase= emart.groupby('Purchase Price')
purchase.mean()
# Out:
#                  Credit Card  CC Security Code
# Purchase Price
# 0.00            2.117485e+15             137.0
# 0.01            4.759624e+15             600.0
# 0.02            2.530742e+15             541.5
# 0.03            9.036526e+13             376.0
# 0.04            3.728702e+14             940.0
# ...                      ...               ...
# 99.92           1.072146e+14             610.0
# 99.93           3.088953e+15             493.0
# 99.95           5.038704e+11             312.0
# 99.97           6.011037e+15             757.0
# 99.99           1.720107e+13             871.0
#
# [6349 rows x 2 columns]

# %%
#Q6. find the highest purchase
purchase.max()
# Out:
#                                                           Address    Lot  \
# Purchase Price
# 0.00               465 Mallory Ways\nNorth Rebecca, RI 82734-1160  93 OH
# 0.01               9202 Baker Forks\nNew Chelseaborough, VA 70852  40 Vx
# 0.02            402 Joseph Tunnel Apt. 219\nMartinmouth, DE 58480  95 xb
# 0.03                             Unit 9279 Box 5039\nDPO AP 86638  69 MM
# 0.04            827 Kathryn Rest Suite 059\nGouldside, PA 4949...  04 ER
# ...                                                           ...    ...
# 99.92                       PSC 1273, Box 3037\nAPO AA 11854-3422  93 HJ
# 99.93           27148 Kathy Cliff Apt. 400\nEast Jillton, TX 5...  37 ou
# 99.95                     672 James Oval\nNew Davidview, KS 91202  07 dT
# 99.97           058 Miranda Locks Suite 792\nPort Davidstad, P...  73 IW
# 99.99                       PSC 6177, Box 1004\nAPO AA 57143-1269  64 Nf
#
#                AM or PM                                       Browser Info  \
# Purchase Price
# 0.00                 PM  Mozilla/5.0 (X11; Linux i686; rv:1.9.6.20) Gec...
# 0.01                 AM  Mozilla/5.0 (iPod; U; CPU iPhone OS 3_3 like M...
# 0.02                 PM  Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10_7...
# 0.03                 PM  Mozilla/5.0 (Macintosh; U; PPC Mac OS X 10_5_0...
# 0.04                 PM  Mozilla/5.0 (iPod; U; CPU iPhone OS 4_2 like M...
# ...                 ...                                                ...
# 99.92                PM  Mozilla/5.0 (compatible; MSIE 8.0; Windows NT ...
# 99.93                PM  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 99.95                PM  Mozilla/5.0 (Windows 98; Win 9x 4.90; it-IT; r...
# 99.97                PM  Mozilla/5.0 (Windows NT 5.0) AppleWebKit/5360 ...
# 99.99                AM  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
#
#                                   Company       Credit Card CC Exp Date  \
# Purchase Price
# 0.00                Lyons, Diaz and Clark  4204500444841766       09/23
# 0.01                   Sanchez-Stephenson  4759624285678506       08/18
# 0.02                         Wagner Group  4720459683484280       08/21
# 0.03                   Washington-Johnson   180054117657378       07/25
# 0.04                       Murphy-Gardner   372870195456666       04/26
# ...                                   ...               ...         ...
# 99.92                     Fisher-Guerrero   210065564716644       08/22
# 99.93                       King and Sons  3088952915231147       04/17
# 99.95                   Fitzpatrick Group      503870406017       05/24
# 99.97                       Olson-Navarro  6011037226242937       03/18
# 99.99           Porter, Johnson and Pratt    30109394842259       11/25
#
#                 CC Security Code                  CC Provider  \
# Purchase Price
# 0.00                         236                VISA 16 digit
# 0.01                         600                VISA 16 digit
# 0.02                         866                   Mastercard
# 0.03                         448                      Voyager
# 0.04                         940  Diners Club / Carte Blanche
# ...                          ...                          ...
# 99.92                        628                      Voyager
# 99.93                        493                   Mastercard
# 99.95                        312                 JCB 15 digit
# 99.97                        757             American Express
# 99.99                        918                VISA 16 digit
#
#                                     Email  \
# Purchase Price
# 0.00                  mjohnson@austin.org
# 0.01                 leesabrina@rojas.com
# 0.02                   rramsey@oliver.com
# 0.03            kimberlyolsen@hotmail.com
# 0.04                     qcross@james.org
# ...                                   ...
# 99.92                 vegaallen@gmail.com
# 99.93                   lpowell@yahoo.com
# 99.95                  mjenkins@gmail.com
# 99.97           brendastewart@dalton.info
# 99.99                   kelli72@gmail.com
#
#                                                   Job       IP Address  \
# Purchase Price
# 0.00                                    Stage manager      43.99.56.59
# 0.01                       Television camera operator   143.139.184.18
# 0.02            Product/process development scientist     69.92.84.253
# 0.03                     Research officer, government    207.65.121.44
# 0.04                                 Surveyor, mining    229.94.185.56
# ...                                               ...              ...
# 99.92                                    Tree surgeon   158.196.81.143
# 99.93                      Television camera operator  110.244.150.130
# 99.95                         Teacher, primary school   192.227.38.104
# 99.97                                   Site engineer    96.79.250.154
# 99.99                             Surveyor, insurance     89.51.92.242
#
#                Language
# Purchase Price
# 0.00                 zh
# 0.01                 es
# 0.02                 ru
# 0.03                 el
# 0.04                 ru
# ...                 ...
# 99.92                it
# 99.93                el
# 99.95                el
# 99.97                de
# 99.99                el
#
# [6349 rows x 13 columns]

# %%
#Q7. find the lowest purchase
purchase.min()
# Out:
#                                                           Address    Lot  \
# Purchase Price
# 0.00            332 Jones Parkways\nEast Katherineville, GA 64230  39 GT
# 0.01               9202 Baker Forks\nNew Chelseaborough, VA 70852  40 Vx
# 0.02                    146 Laura Mission\nNorth Donald, NC 76608  46 Yg
# 0.03                   86103 Ricky Manor\nNunezton, VI 03206-5280  40 Ai
# 0.04            827 Kathryn Rest Suite 059\nGouldside, PA 4949...  04 ER
# ...                                                           ...    ...
# 99.92               408 Russell Club\nSouth Thomas, MT 73554-8846  82 iO
# 99.93           27148 Kathy Cliff Apt. 400\nEast Jillton, TX 5...  37 ou
# 99.95                     672 James Oval\nNew Davidview, KS 91202  07 dT
# 99.97           058 Miranda Locks Suite 792\nPort Davidstad, P...  73 IW
# 99.99                   63773 Shelton Greens\nAshleyton, MA 00493  56 lu
#
#                AM or PM                                       Browser Info  \
# Purchase Price
# 0.00                 AM  Mozilla/5.0 (Macintosh; U; PPC Mac OS X 10_6_9...
# 0.01                 AM  Mozilla/5.0 (iPod; U; CPU iPhone OS 3_3 like M...
# 0.02                 AM  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_7_2 ...
# 0.03                 PM  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_1;...
# 0.04                 PM  Mozilla/5.0 (iPod; U; CPU iPhone OS 4_2 like M...
# ...                 ...                                                ...
# 99.92                AM  Mozilla/5.0 (compatible; MSIE 6.0; Windows 95;...
# 99.93                PM  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 99.95                PM  Mozilla/5.0 (Windows 98; Win 9x 4.90; it-IT; r...
# 99.97                PM  Mozilla/5.0 (Windows NT 5.0) AppleWebKit/5360 ...
# 99.99                AM  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_5_4)...
#
#                            Company       Credit Card CC Exp Date  \
# Purchase Price
# 0.00                Flynn and Sons    30469912089738       01/18
# 0.01            Sanchez-Stephenson  4759624285678506       08/18
# 0.02                 Armstrong PLC   341024981858937       06/19
# 0.03                   Roberts LLC      676398186905       01/25
# 0.04                Murphy-Gardner   372870195456666       04/26
# ...                            ...               ...         ...
# 99.92                 Bond-Oconnor     4363719050674       04/24
# 99.93                King and Sons  3088952915231147       04/17
# 99.95            Fitzpatrick Group      503870406017       05/24
# 99.97                Olson-Navarro  6011037226242937       03/18
# 99.99                  Pitts Group     4292741269160       06/18
#
#                 CC Security Code                  CC Provider  \
# Purchase Price
# 0.00                          38                     Discover
# 0.01                         600                VISA 16 digit
# 0.02                         217                     Discover
# 0.03                         304                      Voyager
# 0.04                         940  Diners Club / Carte Blanche
# ...                          ...                          ...
# 99.92                        592                   Mastercard
# 99.93                        493                   Mastercard
# 99.95                        312                 JCB 15 digit
# 99.97                        757             American Express
# 99.99                        824                      Maestro
#
#                                     Email                          Job  \
# Purchase Price
# 0.00                 jennifer11@baker.com         Biomedical scientist
# 0.01                 leesabrina@rojas.com   Television camera operator
# 0.02                emilypotter@yahoo.com                   IT trainer
# 0.03              heatherpham@hotmail.com  Civil engineer, contracting
# 0.04                     qcross@james.org             Surveyor, mining
# ...                                   ...                          ...
# 99.92           david10@dodson-warner.com              Careers adviser
# 99.93                   lpowell@yahoo.com   Television camera operator
# 99.95                  mjenkins@gmail.com      Teacher, primary school
# 99.97           brendastewart@dalton.info                Site engineer
# 99.99            heatherwoodard@lloyd.com       Surveyor, hydrographic
#
#                      IP Address Language
# Purchase Price
# 0.00             223.47.177.174       it
# 0.01             143.139.184.18       es
# 0.02               66.97.84.200       de
# 0.03             118.191.31.116       de
# 0.04              229.94.185.56       ru
# ...                         ...      ...
# 99.92             111.5.222.164       fr
# 99.93           110.244.150.130       el
# 99.95            192.227.38.104       el
# 99.97             96.79.250.154       de
# 99.99           172.197.216.229       de
#
# [6349 rows x 13 columns]

# %%
#Q8. Find number of people who used English language 'en' on the Emart Shopping website

(emart["Language"]=='en').sum()
# Out:
# 1098

# %%
#Q9. Count how many people have their job title as "engineer" ?
by_title = emart.groupby('Job')
by_title.Job.value_counts()
# Out:
# Job                               Job
# Academic librarian                Academic librarian                  11
# Accommodation manager             Accommodation manager               17
# Accountant, chartered             Accountant, chartered               20
# Accountant, chartered certified   Accountant, chartered certified     18
# Accountant, chartered management  Accountant, chartered management    15
#                                                                       ..
# Water quality scientist           Water quality scientist             18
# Web designer                      Web designer                        20
# Wellsite geologist                Wellsite geologist                  24
# Writer                            Writer                              10
# Youth worker                      Youth worker                        18
# Name: Job, Length: 623, dtype: int64

# %%
#Q10. Count people who purchase during the AM and PM ? 
x= emart['AM'].str.count('AM')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'AM'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-43-4722eafd8a5f> in <module>
#       1 #Q10. Count people who purchase during the AM and PM ?
# ----> 2 x= emart['AM'].str.count('AM')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'AM'

# %%
#Q11. find out the 3 most common Job Titles
emart['Job'].value_counts().nlargest(3)
# Out:
# Interior and spatial designer    31
# Lawyer                           30
# Social researcher                28
# Name: Job, dtype: int64

# %%
#Q12. Find out number of Mastercard holders who purchased over $86
emart['Purchase Price'].gt(86).sum()
# Out:
# 1466

# %%
#Q13.Find out the top 3 email providers

series= emart['Email'].str.split(pat="@",n=1,expand=True)
emart['Email Provider']=series[1]
emart['Email Provider'].value_counts().nlargest(3)
# Out:
# hotmail.com    1638
# yahoo.com      1616
# gmail.com      1605
# Name: Email Provider, dtype: int64

# %% [markdown]
# # Please make sure to have your own solution!
